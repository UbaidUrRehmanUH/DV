# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np # linear algebra
import pandas as pd

# %%
FootballData = pd.read_csv("/Users/usamaali/Desktop/top250-00-19.csv")
# Out:
# /var/folders/dn/4n1jzqt56lg5xqtnf5l3kkj00000gn/T/ipykernel_24176/1415613843.py:1: DtypeWarning: Columns (0,1,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   FootballData = pd.read_csv("/Users/usamaali/Desktop/top250-00-19.csv")

# %%
FootballData.head()
# Out:
#                 Name        Position   Age     Team_from     League_from  \
# 0          Luís Figo    Right Winger  27.0  FC Barcelona          LaLiga
# 1      Hernán Crespo  Centre-Forward  25.0         Parma         Serie A
# 2      Marc Overmars     Left Winger  27.0       Arsenal  Premier League
# 3  Gabriel Batistuta  Centre-Forward  31.0    Fiorentina         Serie A
# 4     Nicolas Anelka  Centre-Forward  21.0   Real Madrid          LaLiga
#
#         Team_to League_to     Season  market-value  Transfer_fee
# 0   Real Madrid    LaLiga  2000-2001       2400000    60000000.0
# 1         Lazio   Serie A  2000-2001       2272400    56810000.0
# 2  FC Barcelona    LaLiga  2000-2001       1600000    40000000.0
# 3       AS Roma   Serie A  2000-2001       1446000    36150000.0
# 4      Paris SG   Ligue 1  2000-2001       1380000    34500000.0

# %%
FootballData = FootballData.head(20)

# %%
sns.countplot(FootballData[:20].League_to)
plt.xlabel("League Names",fontsize=12)
plt.ylabel("Count",fontsize=12)
plt.show()
# Out:
# /Users/usamaali/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(x='Team_from',data=FootballData)
plt.xticks(rotation=90)
plt.xlabel("Team From")
plt.ylabel("Count")
plt.show()
